# %%
# requests library.
# !pip install requests

import requests

url = "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords={key_url}&txtLocation="

response = requests.get(url)

# Response code 200 means SUCCESS.
print("Response Code:",response.status_code)

print(response.text[0:5000])
# Out:
# Response Code: 200
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <head>
#
# 		<link rel="preconnect" href="https://fonts.googleapis.com">
# 		<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
# 		<link href="https://fonts.googleapis.com/css2?family=Nunito+Sans:ital,opsz,wght@0,6..12,200..1000;1,6..12,200..1000&display=swap" rel="stylesheet">
#
# 		<link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/materialize.css?v=8.0.1" rel="stylesheet" type="text/css" media="all"/>
# 		<link href="https://static.timesjobs.com/newtj_css//css/tj_css/usability/global-usability.css?v=8.0.1" rel="stylesheet" type="text/css" media="all"/>
# ...

# %%
# Beautiful Soup.
# find, find_all
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text,"lxml")

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords={key_url}&txtLocation="
response = requests.get(url)

# Response code 200 means SUCCESS.
print("Response Code:",response.status_code)
soup = BeautifulSoup(response.text,"lxml")

title_tag = soup.find("title")
#print(type(title_tag))
print("Page Title: ",title_tag.text if title_tag else "No title found")
# Out:
# Response Code: 200
# Page Title:  {key_url} Jobs

# %%
import requests
from bs4 import BeautifulSoup

key = "python developer"
url = f"https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords={key}&txtLocation="

response = requests.get(url)

# Response code 200 means SUCCESS.
# print("Response Code:",response.status_code)
soup = BeautifulSoup(response.text,"lxml")

title_tag = soup.find("title")
# print(type(title_tag))
print("Page Title: ",title_tag.text if title_tag else "No title found")
# Out:
# Page Title:  python developer Jobs

# %%
# Company Name
# Skills
# Location
# Experience

# Tag = <li> and class = "clearfix job-bx wht-shd-bx"
#/html/body/div[1]/div[5]/section/div[2]/div[2]/ul/li[2]
#<li class="clearfix job-bx wht-shd-bx">
# https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation=

import requests
from bs4 import BeautifulSoup

key = "python developer"
url = f"https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords={key}&txtLocation="

response = requests.get(url)

# Response code 200 means SUCCESS.
# print("Response Code:",response.status_code)
soup = BeautifulSoup(response.text,"lxml")

jobs = soup.find_all("li",class_="clearfix job-bx wht-shd-bx")
# print(len(jobs))
# raw_data = jobs[0].find("h3",class_="joblist-comp-name")
# print(raw_data)

company_names = []
for job in jobs:
    company_tag = job.find("h3",class_="joblist-comp-name")

    if company_tag:
        company_name = company_tag.text.strip()
        company_name = " ".join(company_name.split())
    else:
        company_name = "Not Available"

    company_names.append(company_name)

print(company_names)

# SKILLS
raw_skills = jobs[1].find("div", class_="srp-skills")
skill_tags = raw_skills.find("span", class_=False)
print(skill_tags)
# Out:
# ['INFINITY GROUP', 'SEVEN CONSULTANCY', 'IQVIA', 'SYNECHRON', 'HARMAN INTERNATIONAL', 'Ctd Techs Private Limited', 'CONNECTING 2 WORK', 'CONNECTING 2 WORK', 'CONNECTING 2 WORK', 'CONNECTING 2 WORK', 'cloudxlab', 'FINITE HR CONSUTING PVT LTD', 'Drawsera', 'Mind Digital Group', 'speqto technologies pvt ltd', 'PNR Software Solutions Private Limited', 'AxisTechnolabs', 'pegasus knowledge solutions india pvt ltd.', '3RI Technologies Pvt Ltd', '3Embed Software Technologies', 'v support solutions', 'Bright Vision Technologies', 'Bright Vision Technologies', 'Bright Vision Technologies', 'Bright Vision Technologies']
# <span>
#    					rest
#    				</span>

# %%
skills_list = []

for job in jobs:
    skills_div = job.find("div", class_="srp-skills")

    if skills_div:
        skill_tags = raw_skills.find_all("span", class_=False)
        skills = [skill.text.strip() for skill in skill_tags]
        skills_text = ", ".join(skills)
    else:
        skills_text = "Not Available"

    skills_list.append(skills_text)

print(skills_list)
# Out:
# ['rest, python, oracle, sybase, bi, storage, javascript, nosql, sql, python scripting, java, xml, linux, mysql, unix', 'rest, python, oracle, sybase, bi, storage, javascript, nosql, sql, python scripting, java, xml, linux, mysql, unix', 'rest, python, oracle, sybase, bi, storage, javascript, nosql, sql, python scripting, java, xml, linux, mysql, unix', 'rest, python, oracle, sybase, bi, storage, javascript, nosql, sql, python scripting, java, xml, linux, mysql, unix', 'rest, python, oracle, sybase, bi, storage, javascript, nosql, sql, python scripting, java, xml, linux, mysql, unix', 'rest, python, oracle, sybase, bi, storage, javascript, nosql, sql, python scripting, java, xml, linux, mysql, unix', 'rest, python, oracle, sybase, bi, storage, javascript, nosql, sql, python scripting, java, xml, linux, mysql, unix', 'rest, python, oracle, sybase, bi, storage, javascript, nosql, sql, python scripting, java, xml, linux, mysql, unix', 'rest, python, oracle, sybase, bi, storage, javascrip
# ...

# %%
locations = []
for job in jobs:
    location_tag = job.find("li", class_="srp-zindex location-tru")

    if location_tag:
        location = location_tag.text.strip()
        location = ", ".join(location.split(","))
    else:
        location = "Not Available"

    locations.append(location)

print(locations)
# Out:
# ['Noida/Greater Noida', 'Chennai', 'Bengaluru / Bangalore', 'Bengaluru / Bangalore', 'Bengaluru / Bangalore', 'Chennai,   Bengaluru / Bangalore', 'Bengaluru / Bangalore', 'Thiruvananthapuram', 'Thiruvananthapuram', 'Cochin/ Kochi/ Ernakulam', 'Bengaluru / Bangalore', 'Hyderabad/Secunderabad', 'Mumbai', 'Delhi,   Delhi/NCR', 'Noida/Greater Noida', 'Hyderabad/Secunderabad', 'Ahmedabad', 'Bengaluru / Bangalore', 'Pune', 'Bengaluru / Bangalore', 'Chennai', 'Bengaluru / Bangalore', 'Chennai', 'Delhi,   Gurgaon', 'Hyderabad/Secunderabad']

# %%
experieces = []

for job in jobs:
    li_tags = job.find_all("li")

    exp_text = "Not Available"
    for li in li_tags:
        if li.find("i",class_="srp-icons experience"):
            exp_text = li.text.strip()
            break

    experieces.append(exp_text)

print(experieces)
# Out:
# ['2 - 5 Years', '1 - 4 Years', '2 - 4 Years', '1 - 6 Years', '3 - 6 Years', '3 - 5 Years', '5 - 8 Years', '5 - 10 Years', '5 - 6 Years', '0 - 3 Years', '0 - 3 Years', '4 - 7 Years', '1 - 5 Years', '2 - 5 Years', '2 - 3 Years', '3 - 6 Years', '1 - 4 Years', '0 - 3 Years', '0 - 1 Years', '1 - 3 Years', '2 - 5 Years', '1 - 5 Years', '2 - 5 Years', '2 - 5 Years', '3 - 5 Years']

# %% [markdown]
# # **Create a function job_finder()**

# %%
import requests
from bs4 import BeautifulSoup

def job_finder():
    key= input("Enter your skills for job search: ").strip()
    key_url = key.replace(" ","%20")
    url = f"https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords={key_url}&txtLocation="

    response = requests.get(url)
    soup = BeautifulSoup(response.text,"lxml")
    jobs = soup.find_all("li",class_="clearfix job-bx wht-shd-bx")

    company_names=[]
    skills_list = []
    locations = []
    experiences = []

    for job in jobs:

        # Extract Company.
        company_tag = job.find("h3",class_="joblist-comp-name")

        if company_tag:
            company_name = company_tag.text.strip()
            company_name = " ".join(company_name.split())
        else:
            company_name = "Not Available"

        company_names.append(company_name)


        # Extract Skills.
        skills_div = job.find("div", class_="srp-skills")

        if skills_div:
            skill_tags = raw_skills.find_all("span", class_=False)
            skills = [skill.text.strip() for skill in skill_tags]
            skills_text = ", ".join(skills)
        else:
            skills_text = "Not Available"

        skills_list.append(skills_text)


        # Extract Locations.
        location_tag = job.find("li", class_="srp-zindex location-tru")

        if location_tag:
            location = location_tag.text.strip()
            location = ", ".join(location.split(","))
        else:
            location = "Not Available"
        locations.append(location)

        # Extract Experiences.
        li_tags = job.find_all("li")
        exp_text = "Not Available"
        for li in li_tags:
            if li.find("i",class_="srp-icons experience"):
                exp_text = li.text.strip()
                break

        experiences.append(exp_text)

        result ={
            "Company Name": company_names,
            "Skills":skills_list,
            "Location":locations,
            "Experiences":experiences
        }

    print(f"Extracted {len(company_names)} job postings!!!")
    return result

# %%
jobs = job_finder()
print(jobs)
# Out:
# Enter your skills for job search: python
# Extracted 25 job postings!!!
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def job_finder():
    key = input("Enter your skills for job search: ").strip()
    key_url = key.replace(" ", "%20")

    url = f"https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords={key_url}&txtLocation="
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "lxml")

    jobs = soup.find_all("li", class_="clearfix job-bx wht-shd-bx")

    # Lists to store job data
    company_names = []
    skills_list = []
    locations = []
    experiences = []

    for job in jobs:
        # Company Name
        company_tag = job.find("h3", class_="joblist-comp-name")
        company_name = company_tag.text.strip() if company_tag else "Not Available"
        company_name = " ".join(company_name.split())
        company_names.append(company_name)

        # Skills
        skills_div = job.find("span", class_="srp-skills")
        if skills_div:
            skills_text = skills_div.text.strip()
        else:
            skills_text = "Not Available"
        skills_list.append(skills_text)

        # Location
        location_tag = job.find("li", class_="location")
        if location_tag:
            location = location_tag.text.strip()
        else:
            location = "Not Available"
        locations.append(location)

        # Experience
        li_tags = job.find_all("li")
        exp_text = "Not Available"
        for li in li_tags:
            if li.find("i", class_="srp-icons experience"):
                exp_text = li.text.strip()
                break
        experiences.append(exp_text)

    # Build list of dictionaries (one per job)
    result = []
    for i in range(len(company_names)):
        job_data = {
            "Company Name": company_names[i],
            "Skills": skills_list[i],
            "Location": locations[i],
            "Experience": experiences[i],
        }
        result.append(job_data)

    print(f"\n Extracted {len(result)} job postings!")
    return result

# Run the job finder
jobs = job_finder()

# Create DataFrame and save to CSV
df = pd.DataFrame(jobs)
df.to_csv("scrapped_job_data.csv", index=False)

# Display DataFrame
df.head()
# Out:
# Enter your skills for job search: python
#
#  Extracted 25 job postings!
#            Company Name         Skills       Location   Experience
# 0             SYNECHRON  Not Available  Not Available  1 - 6 Years
# 1        INFINITY GROUP  Not Available  Not Available  2 - 5 Years
# 2     SEVEN CONSULTANCY  Not Available  Not Available  1 - 4 Years
# 3                 IQVIA  Not Available  Not Available  2 - 4 Years
# 4  HARMAN INTERNATIONAL  Not Available  Not Available  3 - 6 Years

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&searchTextSrc=&searchTextText=&txtKeywords=python&txtLocation='

headers = {
    'User-Agent': 'Mozilla/5.0'
}

res = requests.get(url, headers=headers)
soup = BeautifulSoup(res.text, 'lxml')

jobs = soup.find_all("li", class_="clearfix job-bx wht-shd-bx")

print(f"Found {len(jobs)} job blocks")
# Out:
# Found 25 job blocks

# %%
import requests

url = "https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=python&txtLocation="

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'
}

response = requests.get(url, headers=headers)

# Save to a file
with open("timesjobs_page.html", "w", encoding="utf-8") as file:
    file.write(response.text)

print("Page saved as timesjobs_page.html")
# Out:
# Page saved as timesjobs_page.html

# %%
<li class="srp-zindex location-tru"
